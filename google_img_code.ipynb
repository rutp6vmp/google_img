# %% [markdown]
# # 完整程式碼
# ---
# 作業環境:jupyter notebook

# %%
#https://google-images-download.readthedocs.io/en/latest/arguments.html
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

keywords = input(str('請輸入要找的照片:'))
limit  = input(str('請輸入數量:'))

arguments = {"keywords":keywords,"limit":limit,"print_urls":True,"chromedriver":'chromedriver'}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# 請輸入要找的照片:子瑜
# 請輸入數量:30
#
# Item no.: 1 --> Item name = \u5b50\u745c
# Evaluating...
# Starting Download...
# Image URL: https://images.chinatimes.com/newsphoto/2019-08-21/900/20190821002914.jpg
# Completed Image ====> 1.20190821002914.jpg
# Image URL: https://a.ksd-i.com/a/2019-08-23/119549-764607.jpg
# Completed Image ====> 2.119549-764607.jpg
# Image URL: https://s.yimg.com/ny/api/res/1.2/faOwtQf7Lvlzok8qY7Vrbw--~A/YXBwaWQ9aGlnaGxhbmRlcjtzbT0xO3c9ODAw/https://media.zenfs.com/zh-tw/nownews.com/66f46c6203a9f4550211d40b750ed165
# Invalid or missing image format. Skipping...
# Image URL: https://s.yimg.com/ny/api/res/1.2/Q3rUMFrQsnG9S98rm7fBGA--~A/YXBwaWQ9aGlnaGxhbmRlcjtzbT0xO3c9ODAw/https://media.zenfs.com/ko/setn.com.tw/3cecdb11ad33ac09db45b7e813b01100
# Invalid or missing image format. Skipping...
# Image URL: https://static.juksy.com/files/articles/84920/5bf3f1c88ea71.jpg?m=widen&i=800&q=75
# Completed Image ====> 3.5bf3f1c88ea71.jpg
# ...

# %%
import os
from PIL import Image

img_dir = r"./photo/"
for filename in os.listdir(img_dir):
    try :
        with Image.open(img_dir + "/" + filename) as im:
             print('ok')
    except :
        print(img_dir + "/" + filename)
        os.remove(img_dir + "/" + filename)
